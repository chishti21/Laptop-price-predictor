# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('laptop_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
#Data preprocessing

# %%
data.reset_index(inplace=True)

# %%
data.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %%
data.describe()
# Out:
#             index       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))

# %%
columns_to_scale=['Inches','Price']

# %%
data[columns_to_scale]=scaler.fit_transform(data[columns_to_scale])

# %%
data['Ram']=data['Ram'].str.replace('GB','')

# %%
data['Ram']=data['Ram'].astype('int32')

# %%
data['Weight']=data['Weight'].str.replace('kg','')

# %%
data['Weight']=data['Weight'].astype('float')

# %%
columns_to_scale=['Ram','Weight']
data[columns_to_scale]=scaler.fit_transform(data[columns_to_scale])

# %%
def processor(x):
  if 'Intel Core i7' in x:
    return 'Intel Core i7'
  elif  'Intel Core i5' in x:
    return 'Intel Core i5'
  elif  'Intel Core i3' in x:
    return 'Intel Core i3'
  else:
    return 'Other'

# %%
data['Processor']=data['Cpu'].apply(processor)

# %%
# Apply split to each element in the 'Gpu' column and extract the first word
data['Gpu'] = data['Gpu'].apply(lambda x: str(x).split()[0] if pd.notnull(x) else x)

# %%
data.head()
# Out:
#    index Company   TypeName    Inches                    ScreenResolution  \
# 0      0   Apple  Ultrabook  0.385542  IPS Panel Retina Display 2560x1600
# 1      1   Apple  Ultrabook  0.385542                            1440x900
# 2      2      HP   Notebook  0.662651                   Full HD 1920x1080
# 3      3   Apple  Ultrabook  0.638554  IPS Panel Retina Display 2880x1800
# 4      4   Apple  Ultrabook  0.385542  IPS Panel Retina Display 2560x1600
#
#                           Cpu       Ram               Memory    Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz  0.096774            128GB SSD  Intel  macOS
# 1        Intel Core i5 1.8GHz  0.096774  128GB Flash Storage  Intel  macOS
# 2  Intel Core i5 7200U 2.5GHz  0.096774            256GB SSD  Intel  No OS
# 3        Intel Core i7 2.7GHz  0.225806            512GB SSD    AMD  macOS
# 4        Intel Core i5 3.1GHz  0.096774            256GB SSD  Intel  macOS
#
#      Weight     Price      Processor
# 0  0.169576  0.196741  Intel Core i5
# 1  0.162095  0.122353  Intel Core i5
# 2  0.291771  0.067679  Intel Core i5
# 3  0.284289  0.398895  Intel Core i7
# 4  0.169576  0.275038  Intel Core i5

# %%
import re
# Extract only the SSD portion using regex with error handling
data['SSD'] = data['Memory'].apply(lambda x: re.search(r'(\d+GB) SSD', str(x)).group(1) if pd.notnull(x) and re.search(r'(\d+GB) SSD', str(x)) else None)

# %%
import re
# Extract only the HDD portion using regex with error handling
data['HDD'] = data['Memory'].apply(lambda x: re.search(r'(\d+GB) HDD', str(x)).group(1) if pd.notnull(x) and re.search(r'(\d+GB) HDD', str(x)) else None)

# %%
def ips(text):
  if 'IPS' in text:
    return 1
  else:
    return 0

# %%
def Screen(text):
  if 'Touchscreen' in text:
    return 1
  else:
    return 0

# %%
data['IPS']=data['ScreenResolution'].apply(ips)
data['Touchscreen']=data['ScreenResolution'].apply(Screen)

# %%
import re
# Assuming 'data' is your DataFrame
data['ScreenResolution'] = data['ScreenResolution'].apply(lambda x: re.search(r'\d+x\d+', str(x)).group() if pd.notnull(x) else x)

# %%
data.drop(columns=['Cpu','Memory','index'], inplace=True)

# %%
data=data.rename(columns={'Company':'Brand','TypeName':'Laptop Type','Inches':'Screen Size','OpSys':'OS','Hard Drive':'HDD','IPS':'Ips Display'})

# %%
data=data.rename(columns={'HDD':'Hard Drive'})

# %%
data
# Out:
#        Brand         Laptop Type  Screen Size ScreenResolution       Ram  \
# 0      Apple           Ultrabook     0.385542        2560x1600  0.096774
# 1      Apple           Ultrabook     0.385542         1440x900  0.096774
# 2         HP            Notebook     0.662651        1920x1080  0.096774
# 3      Apple           Ultrabook     0.638554        2880x1800  0.225806
# 4      Apple           Ultrabook     0.385542        2560x1600  0.096774
# ...      ...                 ...          ...              ...       ...
# 1298  Lenovo  2 in 1 Convertible     0.469880        1920x1080  0.032258
# 1299  Lenovo  2 in 1 Convertible     0.385542        3200x1800  0.225806
# 1300  Lenovo            Notebook     0.469880         1366x768  0.000000
# 1301      HP            Notebook     0.662651         1366x768  0.064516
# 1302    Asus            Notebook     0.662651         1366x768  0.032258
#
#         Gpu          OS    Weight     Price      Processor    SSD Hard Drive  \
# 0     Intel       macOS  0.169576  0.196741  Intel Core i5  128GB       None
# 1     Intel       macOS  0.162095  0.122353  Intel Core i5   None       None
# 2     Intel       No OS  0.291771  0.067679  Intel Core i5  256GB       None
# 3       AMD       macOS  0.284289  0.398895  Intel Core i7  512GB       None
# 4     Intel       macOS  0.169576  0.275038  Intel Core i5  256GB       None
# ...     ...         ...       ...       ...            ...    ...        ...
# 1298  Intel  Windows 10  0.276808  0.078312  Intel Core i7  128GB       None
# 1299  Intel  Windows 10  0.152120  0.223629  Intel Core i7  512GB       None
# 1300  Intel  Windows 10  0.201995  0.009283          Other   None       None
# 1301    AMD  Windows 10  0.374065  0.099578  Intel Core i7   None       None
# 1302  Intel  Windows 10  0.376559  0.032911          Other   None      500GB
#
#       Ips Display  Touchscreen
# 0               1            0
# 1               0            0
# 2               0            0
# 3               1            0
# 4               1            0
# ...           ...          ...
# 1298            1            1
# 1299            1            1
# 1300            0            0
# 1301            0            0
# 1302            0            0
#
# [1303 rows x 14 columns]

# %%
data['Hard Drive']=data['Hard Drive'].str.replace('GB','')

# %%
data['SSD']=data['SSD'].str.replace('GB','')

# %%
columns_to_scale=['SSD','Hard Drive']
data[columns_to_scale]=scaler.fit_transform(data[columns_to_scale])

# %%
len(data)
# Out:
# 1303

# %%
data['Hard Drive'].isnull().sum()
# Out:
# 1167

# %%
data['SSD'].isnull().sum()
# Out:
# 476

# %%
data['Hard Drive']=data['Hard Drive'].fillna(0)

# %%
data['SSD']=data['SSD'].fillna(0)

# %%
data['Hard Drive'].value_counts()
# Out:
# Hard Drive
# 0.000000    1168
# 1.000000     134
# 0.205128       1
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['Brand', 'Laptop Type', 'Screen Size', 'ScreenResolution', 'Ram', 'Gpu',
#        'OS', 'Weight', 'Price', 'Processor', 'SSD', 'Hard Drive',
#        'Ips Display', 'Touchscreen'],
#       dtype='object')

# %%
data['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# 1920x1080    841
# 1366x768     308
# 3840x2160     43
# 3200x1800     27
# 2560x1440     23
# 1600x900      23
# 2560x1600      6
# 2304x1440      6
# 2256x1504      6
# 1920x1200      5
# 1440x900       4
# 2880x1800      4
# 2400x1600      4
# 2160x1440      2
# 2736x1824      1
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    Brand Laptop Type  Screen Size ScreenResolution       Ram    Gpu     OS  \
# 0  Apple   Ultrabook     0.385542        2560x1600  0.096774  Intel  macOS
# 1  Apple   Ultrabook     0.385542         1440x900  0.096774  Intel  macOS
# 2     HP    Notebook     0.662651        1920x1080  0.096774  Intel  No OS
# 3  Apple   Ultrabook     0.638554        2880x1800  0.225806    AMD  macOS
# 4  Apple   Ultrabook     0.385542        2560x1600  0.096774  Intel  macOS
#
#      Weight     Price      Processor       SSD  Hard Drive  Ips Display  \
# 0  0.169576  0.196741  Intel Core i5  0.238095         0.0            1
# 1  0.162095  0.122353  Intel Core i5  0.000000         0.0            0
# 2  0.291771  0.067679  Intel Core i5  0.492063         0.0            0
# 3  0.284289  0.398895  Intel Core i7  1.000000         0.0            1
# 4  0.169576  0.275038  Intel Core i5  0.492063         0.0            1
#
#    Touchscreen
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
data = data.sample(frac=1, random_state=42)

# %%
data['Gpu'].value_counts()
# Out:
# Gpu
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
data = pd.get_dummies(data, columns=['Brand', 'Laptop Type', 'ScreenResolution', 'Gpu', 'OS', 'Processor'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1303 entries, 479 to 1126
# Data columns (total 65 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Screen Size                     1303 non-null   float64
#  1   Ram                             1303 non-null   float64
#  2   Weight                          1303 non-null   float64
#  3   Price                           1303 non-null   float64
#  4   SSD                             1303 non-null   float64
#  5   Hard Drive                      1303 non-null   float64
#  6   Ips Display                     1303 non-null   int64
#  7   Touchscreen                     1303 non-null   int64
#  8   Brand_Acer                      1303 non-null   bool
#  9   Brand_Apple                     1303 non-null   bool
#  10  Brand_Asus                      1303 non-null   bool
#  11  Brand_Chuwi                     1303 non-null   bool
#  12  Brand_Dell                      1303 non-null   bool
#  13  Brand_Fujitsu                   1303 non-null   bool
#  14  Brand_Google                    1303 non-null   bool
#  15  Brand_HP                        1303 non-null   bool
#  16  Brand_Huawei                    1303 non-null   bool
#  17  Brand_LG                        1303 non-null   bool
#  18  Brand_Lenovo                    1303 non-null   bool
#  19  Brand_MSI                       1303 non-null   bool
#  20  Brand_Mediacom                  1303 non-null   bool
#  21  Brand_Microsoft                 1303 non-null   bool
#  22  Brand_Razer                     1303 non-null   bool
#  23  Brand_Samsung                   1303 non-null   bool
#  24  Brand_Toshiba                   1303 non-null   bool
#  25  Brand_Vero                      1303 non-null   bool
#  26  Brand_Xiaomi                    1303 non-null   bool
#  27  Laptop Type_2 in 1 Convertible  1303 non-null   bool
#  28  Laptop Type_Gaming              1303 non-null   bool
#  29  Laptop Type_Netbook             1303 non-null   bool
#  30  Laptop Type_Notebook            1303 non-null   bool
#  31  Laptop Type_Ultrabook           1303 non-null   bool
#  32  Laptop Type_Workstation         1303 non-null   bool
#  33  ScreenResolution_1366x768       1303 non-null   bool
#  34  ScreenResolution_1440x900       1303 non-null   bool
#  35  ScreenResolution_1600x900       1303 non-null   bool
#  36  ScreenResolution_1920x1080      1303 non-null   bool
#  37  ScreenResolution_1920x1200      1303 non-null   bool
#  38  ScreenResolution_2160x1440      1303 non-null   bool
#  39  ScreenResolution_2256x1504      1303 non-null   bool
#  40  ScreenResolution_2304x1440      1303 non-null   bool
#  41  ScreenResolution_2400x1600      1303 non-null   bool
#  42  ScreenResolution_2560x1440      1303 non-null   bool
#  43  ScreenResolution_2560x1600      1303 non-null   bool
#  44  ScreenResolution_2736x1824      1303 non-null   bool
#  45  ScreenResolution_2880x1800      1303 non-null   bool
#  46  ScreenResolution_3200x1800      1303 non-null   bool
#  47  ScreenResolution_3840x2160      1303 non-null   bool
#  48  Gpu_AMD                         1303 non-null   bool
#  49  Gpu_ARM                         1303 non-null   bool
#  50  Gpu_Intel                       1303 non-null   bool
#  51  Gpu_Nvidia                      1303 non-null   bool
#  52  OS_Android                      1303 non-null   bool
#  53  OS_Chrome OS                    1303 non-null   bool
#  54  OS_Linux                        1303 non-null   bool
#  55  OS_Mac OS X                     1303 non-null   bool
#  56  OS_No OS                        1303 non-null   bool
#  57  OS_Windows 10                   1303 non-null   bool
#  58  OS_Windows 10 S                 1303 non-null   bool
#  59  OS_Windows 7                    1303 non-null   bool
#  60  OS_macOS                        1303 non-null   bool
#  61  Processor_Intel Core i3         1303 non-null   bool
#  62  Processor_Intel Core i5         1303 non-null   bool
#  63  Processor_Intel Core i7         1303 non-null   bool
#  64  Processor_Other                 1303 non-null   bool
# dtypes: bool(57), float64(6), int64(2)
# memory usage: 164.1 KB

# %%
data.head()
# Out:
#       Screen Size       Ram    Weight     Price       SSD  Hard Drive  \
# 479      0.385542  0.096774  0.089776  0.252827  0.492063         0.0
# 1022     0.385542  0.096774  0.104738  0.164557  0.492063         0.0
# 298      0.662651  0.064516  0.426434  0.054852  0.000000         0.0
# 1265     0.662651  0.096774  0.476309  0.122363  0.000000         0.0
# 774      0.289157  0.032258  0.142145  0.180591  0.492063         0.0
#
#       Ips Display  Touchscreen  Brand_Acer  Brand_Apple  ...  OS_Mac OS X  \
# 479             1            0       False        False  ...        False
# 1022            1            0       False        False  ...        False
# 298             0            0       False        False  ...        False
# 1265            1            0       False        False  ...        False
# 774             0            0       False        False  ...        False
#
#       OS_No OS  OS_Windows 10  OS_Windows 10 S  OS_Windows 7  OS_macOS  \
# 479      False           True            False         False     False
# 1022     False           True            False         False     False
# 298      False           True            False         False     False
# 1265     False           True            False         False     False
# 774      False           True            False         False     False
#
#       Processor_Intel Core i3  Processor_Intel Core i5  \
# 479                     False                     True
# 1022                    False                     True
# 298                     False                    False
# 1265                    False                    False
# 774                     False                     True
#
#       Processor_Intel Core i7  Processor_Other
# 479                     False            False
# 1022                    False            False
# 298                     False             True
# 1265                     True            False
# 774                     False            False
#
# [5 rows x 65 columns]

# %%
data.columns
# Out:
# Index(['Screen Size', 'Ram', 'Weight', 'Price', 'SSD', 'Hard Drive',
#        'Ips Display', 'Touchscreen', 'Brand_Acer', 'Brand_Apple', 'Brand_Asus',
#        'Brand_Chuwi', 'Brand_Dell', 'Brand_Fujitsu', 'Brand_Google',
#        'Brand_HP', 'Brand_Huawei', 'Brand_LG', 'Brand_Lenovo', 'Brand_MSI',
#        'Brand_Mediacom', 'Brand_Microsoft', 'Brand_Razer', 'Brand_Samsung',
#        'Brand_Toshiba', 'Brand_Vero', 'Brand_Xiaomi',
#        'Laptop Type_2 in 1 Convertible', 'Laptop Type_Gaming',
#        'Laptop Type_Netbook', 'Laptop Type_Notebook', 'Laptop Type_Ultrabook',
#        'Laptop Type_Workstation', 'ScreenResolution_1366x768',
#        'ScreenResolution_1440x900', 'ScreenResolution_1600x900',
#        'ScreenResolution_1920x1080', 'ScreenResolution_1920x1200',
#        'ScreenResolution_2160x1440', 'ScreenResolution_2256x1504',
#        'ScreenResolution_2304x1440', 'ScreenResolution_2400x1600',
#        'ScreenResolution_2560x1440', 'ScreenResolution_2560x1600',
#        'ScreenResolution_2736x1824', 'ScreenResolution_2880x1800',
#        'ScreenResolution_3200x1800', 'ScreenResolution_3840x2160', 'Gpu_AMD',
#        'Gpu_ARM', 'Gpu_Intel', 'Gpu_Nvidia', 'OS_Android', 'OS_Chrome OS',
#        'OS_Linux', 'OS_Mac OS X', 'OS_No OS', 'OS_Windows 10',
#        'OS_Windows 10 S', 'OS_Windows 7', 'OS_macOS',
#        'Processor_Intel Core i3', 'Processor_Intel Core i5',
#        'Processor_Intel Core i7', 'Processor_Other'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
x=data.drop(columns=['Price'])
y=data['Price']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)


print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (1042, 64)
# x_test shape: (261, 64)
# y_train shape: (1042,)
# y_test shape: (261,)

# %%
from sklearn.linear_model import LinearRegression

# Initialize the model
model = LinearRegression()

# Fit the model
model.fit(x_train, y_train)

# Predict
y_pred = model.predict(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize the model
model = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model
model.fit(x_train, y_train)

# Predict
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Calculate MSE and R²
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)


print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'R²: {r2}')
# Out:
# MSE: 0.0019843533380916626
# RMSE: 0.0445460810632278
# R²: 0.8464690277072039
